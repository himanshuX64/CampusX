# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
requests.get('https://www.ambitionbox.com/overview/tcs-overview').text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;overview&#47;tcs&#45;overview" on this server.<P>\nReference&#32;&#35;18&#46;368d2c31&#46;1762797511&#46;1cdd95c6\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;368d2c31&#46;1762797511&#46;1cdd95c6</P>\n</BODY>\n</HTML>\n'

# %%
headers={"User-Agent":"Mozilla/5.0(Macintosh; Intel Mac Os x 10.14;rv:66.0) gecko/20100101 firefox/66.0"}
webpage=requests.get('https://www.ambitionbox.com/overview/tcs-overview',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <link as="image" fetchpriority="high" href="https://static.ambitionbox.com/assets/v2/images/rs:fit:200:200:false:false/aHR0cHM6Ly9tZWRpYS5uYXVrcmkuY29tL21lZGlhL2FiY29tcGxvZ28vdGNzLW9yaWdpbmFsLmpwZw.webp" rel="preload"/>
#   <title>
#    Life at TCS: Culture, Salary, Reviews, Interviews &amp; more
#   </title>
#   <meta content="Life at TCS: Culture, Salary, Reviews, Interviews &amp; more" name="title"/>
#   <meta content="Get an inside look of TCS — culture, pay, reviews, interview questions, job openings, corporate offices, peer comparison and more on AmbitionBox" name="description"/>
#   <meta content="width=device-width,initial-scale=1, minimum-scale=1, interactive-widget=resizes-content" name="viewport"/>
#   <link href="https://static.ambitionbox.com/alpha/img/supporting-images/browser_icon_16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %% [raw]
# # find all p tag

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# TCS
# Job security
# Promotions, Salary, Work satisfaction
# Reviews
# Interviews
# Salaries
# Users
# Reviews
# Interviews
# Salaries
# Users
# Made with ❤️ in India. Trademarks belong to their respective owners. All rights reserved © 2025 Info Edge (India) Ltd.

# %%
soup.find_all('p',class_='Overall Rating')
# Out:
# []

# %%
soup.find_all('a')
# Out:
# [<a aria-label="AmbitionBox" class="css-146c3p1 ml-1 font-pn-700 text-base md:text-[20px] md:leading-5 text-neutral" dir="auto" href="/" role="link">AmbitionBox</a>,
#  <a class="flex-1 flex flex-col items-center justify-center md:flex-row px-2 pt-1 pb-2.5 md:py-0 bg-[#F8F8FF] border-r border-l border-card-border md:flex-row" data-testid="" href="/overview/tcs-overview" target="_self" title="TCS Overview"><div class="ml-1 md:ml-0 md:mr-1.5" style="position:relative;width:16px;height:16px;background-color:transparent"><img alt="" data-nimg="fill" decoding="async" loading="lazy" src="https://static.ambitionbox.com/static/middleNavbar/about.png" style="position:absolute;height:100%;width:100%;left:0;top:0;right:0;bottom:0;object-fit:cover;color:transparent;border-radius:inherit"/></div><div class="css-175oi2r flex-row items-center mt-0.5 md:mt-0"><div class="css-146c3p1 font-pn-600 text-xs text-primary-text md:text-[14px] md:leading-[20px]" dir="auto">About</div></div></a>,
# ...

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 0

# %%
name=[]
rating=[]
review=[]
ctype=[]
hq=[]
old=[]
employees=[]
des=[]

for in comapnay

# %%
# see on Campus X Ytube video 18
