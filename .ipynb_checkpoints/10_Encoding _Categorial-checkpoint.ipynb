# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/salaries_dt.csv')
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
df.isnull().sum()
# Out:
# company                  0
# job                      0
# degree                   0
# salary_more_then_100k    0
# dtype: int64

# %%
df=df.iloc[:,0:9]
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:2],df.,test_size=0.1,random_state=0)

# %%
X_train
# Out:
#        company                  job
# 13    facebook     business manager
# 4       google  computer programmer
# 2       google     business manager
# 14    facebook  computer programmer
# 10    facebook      sales executive
# 7   abc pharma  computer programmer
# 15    facebook  computer programmer
# 11    facebook      sales executive
# 3       google     business manager
# 0       google      sales executive
# 5       google  computer programmer
# 12    facebook     business manager

# %%
y_train
# Out:
# 13      masters
# 4     bachelors
# 2     bachelors
# 14    bachelors
# 10    bachelors
# 7     bachelors
# 15      masters
# 11      masters
# 3       masters
# 0     bachelors
# 5       masters
# 12    bachelors
# Name: degree, dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['abc pharma','facebook','google'],['sales executive','business manager','computer programmer']])

# %%
oe.fit(X_train)
# Out:
# OrdinalEncoder(categories=[['abc pharma', 'facebook', 'google'],
#                            ['sales executive', 'business manager',
#                             'computer programmer']])

# %%
X_train_oe=oe.transform(X_train)
X_train_oe
# Out:
# C:\Users\91886\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 X_train_oe=oe.transform(X_train)
#       2 X_train_oe
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
# ...
