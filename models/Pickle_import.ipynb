# %%
import pickle
import numpy as np

# %%
ohe_sex=pickle.load(open('ohe_sex.pkl','rb'))
ohe_embarked=pickle.load(open('ohe_embarked.pkl','rb'))
dtc=pickle.load(open('dtc.pkl','rb'))

# %% [markdown]
# # Assume User input

# %%
# pclass/gender/age/sibsp/parch/fare/Embarked
test_input=np.array([3,'male',31,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[3, 'male', 31, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex=ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# C:\Users\91886\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 test_input_sex=test_input_sex.toarray()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'toarray'

# %%
test_input_embarked=ohe_embarked.transform(test_input[:,-1].reshape(1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_input_embarked=ohe_embarked.transform(test_input[:,-1].reshape(1,1))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1043, in OneHotEncoder.transform(self, X)
#    1038     warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1039         "ignore",
#    1040         "infrequent_if_exist",
#    1041     }
#    1042     handle_unknown = self.handle_unknown
# -> 1043 X_int, X_mask = self._transform(
#    1044     X,
#    1045     handle_unknown=handle_unknown,
#    1046     ensure_all_finite="allow-nan",
#    1047     warn_on_unknown=warn_on_unknown,
#    1048 )
#    1050 n_samples, n_features = X_int.shape
#    1052 if self._drop_idx_after_grouping is not None:
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:202, in _BaseEncoder._transform(self, X, handle_unknown, ensure_all_finite, warn_on_unknown, ignore_category_indices)
#     198 X_list, n_samples, n_features = self._check_X(
#     199     X, ensure_all_finite=ensure_all_finite
#     200 )
#     201 _check_feature_names(self, X, reset=False)
# --> 202 _check_n_features(self, X, reset=False)
#     204 X_int = np.zeros((n_samples, n_features), dtype=int)
#     205 X_mask = np.ones((n_samples, n_features), dtype=bool)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2829, in _check_n_features(estimator, X, reset)
#    2826     return
#    2828 if n_features != estimator.n_features_in_:
# -> 2829     raise ValueError(
#    2830         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831         f"is expecting {estimator.n_features_in_} features as input."
#    2832     )
#
# ValueError: X has 1 features, but OneHotEncoder is expecting 3 features as input.

# %%
test_input_age=test_input[:,2].reshape(1,1))
