# %%
import pandas as pd

# %% [markdown]
# # working on JSON

# %% [markdown]
# # read_json

# %%
df=pd.read_json('train.json')
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# # working on SQL

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      ----------- ---------------------------- 3.4/11.9 MB 14.5 MB/s eta 0:00:01
#      -------------------- ------------------- 6.0/11.9 MB 13.4 MB/s eta 0:00:01
#      --------------------------- ------------ 8.1/11.9 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 10.5/11.9 MB 12.6 MB/s eta 0:00:01
#      --------------------------------------- 11.9/11.9 MB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp313-cp313-win_amd64.whl size=247959 sha256=eb1a405e4478c980063ed7444256225cc594ae3a9646a987fefcb00990cac6da
#   Stored in directory: c:\users\91886\appdata\local\pip\cache\wheels\4e\c1\23\9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# ...

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host='loaclhost',user='root',password='',database='world')

# %%
pd.read_sql_query("select * from city")
